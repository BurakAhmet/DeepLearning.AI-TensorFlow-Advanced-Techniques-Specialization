# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 995us/sample - loss: 215.4293 - y1_output_loss: 102.7481 - y2_output_loss: 110.6983 - y1_output_root_mean_squared_error: 10.1837 - y2_output_root_mean_squared_error: 10.5698 - val_loss: 38.0085 - val_y1_output_loss: 14.3585 - val_y2_output_loss: 24.1401 - val_y1_output_root_mean_squared_error: 3.6614 - val_y2_output_root_mean_squared_error: 4.9601
# Epoch 2/500
# 614/614 [==============================] - 0s 157us/sample - loss: 37.3101 - y1_output_loss: 14.1355 - y2_output_loss: 22.8665 - y1_output_root_mean_squared_error: 3.7772 - y2_output_root_mean_squared_error: 4.8003 - val_loss: 27.1683 - val_y1_output_loss: 14.6710 - val_y2_output_loss: 14.2970 - val_y1_output_root_mean_squared_error: 3.6496 - val_y2_output_root_mean_squared_error: 3.7214
# Epoch 3/500
# 614/614 [==============================] - 0s 152us/sample - loss: 26.7825 - y1_output_loss: 11.0407 - y2_output_loss: 15.6232 - y1_output_root_mean_squared_error: 3.3328 - y2_output_root_mean_squared_error: 3.9591 - val_loss: 18.4216 - val_y1_output_loss: 7.3530 - val_y2_output_loss: 10.9124 - val_y1_output_root_mean_squared_error: 2.6911 - val_y2_output_root_mean_squared_error: 3.3436
# Epoch 4/500
# 614/614 [==============================] - 0s 159us/sample - loss: 21.5899 - y1_output_loss: 9.4189 - y2_output_loss: 12.4237 - y1_output_root_mean_squared_error: 3.0228 - y2_output_root_mean_squared_error: 3.5289 - val_loss: 20.1018 - val_y1_output_loss: 7.0601 - val_y2_output_loss: 12.4481 - val_y1_output_root_mean_squared_error: 2.6809 - val_y2_output_root_mean_squared_error: 3.5937
# Epoch 5/500
# 614/614 [==============================] - 0s 151us/sample - loss: 25.7167 - y1_output_loss: 9.7067 - y2_output_loss: 15.8129 - y1_output_root_mean_squared_error: 3.1281 - y2_output_root_mean_squared_error: 3.9914 - val_loss: 16.8767 - val_y1_output_loss: 6.8664 - val_y2_output_loss: 10.0720 - val_y1_output_root_mean_squared_error: 2.5787 - val_y2_output_root_mean_squared_error: 3.1980
# Epoch 6/500
# 614/614 [==============================] - 0s 148us/sample - loss: 22.9792 - y1_output_loss: 9.0353 - y2_output_loss: 13.7548 - y1_output_root_mean_squared_error: 3.0167 - y2_output_root_mean_squared_error: 3.7254 - val_loss: 17.3382 - val_y1_output_loss: 7.1180 - val_y2_output_loss: 9.9635 - val_y1_output_root_mean_squared_error: 2.6582 - val_y2_output_root_mean_squared_error: 3.2050
# Epoch 7/500
# 614/614 [==============================] - 0s 146us/sample - loss: 19.7799 - y1_output_loss: 8.3750 - y2_output_loss: 11.4562 - y1_output_root_mean_squared_error: 2.9003 - y2_output_root_mean_squared_error: 3.3717 - val_loss: 18.4871 - val_y1_output_loss: 7.6808 - val_y2_output_loss: 10.9173 - val_y1_output_root_mean_squared_error: 2.7319 - val_y2_output_root_mean_squared_error: 3.3202
# Epoch 8/500
# 614/614 [==============================] - 0s 146us/sample - loss: 25.7626 - y1_output_loss: 9.1647 - y2_output_loss: 16.4431 - y1_output_root_mean_squared_error: 3.0381 - y2_output_root_mean_squared_error: 4.0660 - val_loss: 22.6266 - val_y1_output_loss: 8.6996 - val_y2_output_loss: 14.2469 - val_y1_output_root_mean_squared_error: 2.8918 - val_y2_output_root_mean_squared_error: 3.7768
# Epoch 9/500
# 614/614 [==============================] - 0s 141us/sample - loss: 21.2711 - y1_output_loss: 8.3888 - y2_output_loss: 12.6876 - y1_output_root_mean_squared_error: 2.9098 - y2_output_root_mean_squared_error: 3.5783 - val_loss: 16.4125 - val_y1_output_loss: 6.4529 - val_y2_output_loss: 9.7394 - val_y1_output_root_mean_squared_error: 2.5245 - val_y2_output_root_mean_squared_error: 3.1685
# Epoch 10/500
# 614/614 [==============================] - 0s 143us/sample - loss: 22.5109 - y1_output_loss: 8.6178 - y2_output_loss: 13.7648 - y1_output_root_mean_squared_error: 2.9366 - y2_output_root_mean_squared_error: 3.7266 - val_loss: 15.2516 - val_y1_output_loss: 6.1364 - val_y2_output_loss: 8.9236 - val_y1_output_root_mean_squared_error: 2.4689 - val_y2_output_root_mean_squared_error: 3.0259
# Epoch 11/500
# 614/614 [==============================] - 0s 141us/sample - loss: 23.2595 - y1_output_loss: 9.1443 - y2_output_loss: 14.9219 - y1_output_root_mean_squared_error: 2.9778 - y2_output_root_mean_squared_error: 3.7937 - val_loss: 104.7480 - val_y1_output_loss: 23.6950 - val_y2_output_loss: 80.1711 - val_y1_output_root_mean_squared_error: 4.8463 - val_y2_output_root_mean_squared_error: 9.0145
# Epoch 12/500
# 614/614 [==============================] - 0s 147us/sample - loss: 21.4656 - y1_output_loss: 8.1298 - y2_output_loss: 13.2498 - y1_output_root_mean_squared_error: 2.8605 - y2_output_root_mean_squared_error: 3.6446 - val_loss: 26.5101 - val_y1_output_loss: 8.0649 - val_y2_output_loss: 18.1250 - val_y1_output_root_mean_squared_error: 2.8350 - val_y2_output_root_mean_squared_error: 4.2980
# Epoch 13/500
# 614/614 [==============================] - 0s 152us/sample - loss: 19.7304 - y1_output_loss: 7.5718 - y2_output_loss: 12.1255 - y1_output_root_mean_squared_error: 2.7498 - y2_output_root_mean_squared_error: 3.4884 - val_loss: 15.0276 - val_y1_output_loss: 5.5602 - val_y2_output_loss: 9.0455 - val_y1_output_root_mean_squared_error: 2.3784 - val_y2_output_root_mean_squared_error: 3.0611
# Epoch 14/500
# 614/614 [==============================] - 0s 149us/sample - loss: 24.9917 - y1_output_loss: 8.3802 - y2_output_loss: 16.9749 - y1_output_root_mean_squared_error: 2.8819 - y2_output_root_mean_squared_error: 4.0849 - val_loss: 17.2665 - val_y1_output_loss: 7.3396 - val_y2_output_loss: 9.6983 - val_y1_output_root_mean_squared_error: 2.7173 - val_y2_output_root_mean_squared_error: 3.1437
# Epoch 15/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.4401 - y1_output_loss: 6.7342 - y2_output_loss: 10.5935 - y1_output_root_mean_squared_error: 2.6000 - y2_output_root_mean_squared_error: 3.2680 - val_loss: 15.0266 - val_y1_output_loss: 7.0092 - val_y2_output_loss: 7.9042 - val_y1_output_root_mean_squared_error: 2.6434 - val_y2_output_root_mean_squared_error: 2.8353
# Epoch 16/500
# 614/614 [==============================] - 0s 146us/sample - loss: 15.8866 - y1_output_loss: 6.3059 - y2_output_loss: 9.7581 - y1_output_root_mean_squared_error: 2.4907 - y2_output_root_mean_squared_error: 3.1118 - val_loss: 32.2802 - val_y1_output_loss: 7.3606 - val_y2_output_loss: 23.8558 - val_y1_output_root_mean_squared_error: 2.7527 - val_y2_output_root_mean_squared_error: 4.9702
# Epoch 17/500
# 614/614 [==============================] - 0s 151us/sample - loss: 15.0278 - y1_output_loss: 6.0944 - y2_output_loss: 9.0129 - y1_output_root_mean_squared_error: 2.4649 - y2_output_root_mean_squared_error: 2.9920 - val_loss: 33.0074 - val_y1_output_loss: 7.2617 - val_y2_output_loss: 24.6692 - val_y1_output_root_mean_squared_error: 2.7429 - val_y2_output_root_mean_squared_error: 5.0481
# Epoch 18/500
# 614/614 [==============================] - 0s 143us/sample - loss: 15.7995 - y1_output_loss: 6.0209 - y2_output_loss: 9.7803 - y1_output_root_mean_squared_error: 2.4512 - y2_output_root_mean_squared_error: 3.1291 - val_loss: 31.5070 - val_y1_output_loss: 6.6844 - val_y2_output_loss: 23.8229 - val_y1_output_root_mean_squared_error: 2.6157 - val_y2_output_root_mean_squared_error: 4.9664
# Epoch 19/500
# 614/614 [==============================] - 0s 146us/sample - loss: 13.4443 - y1_output_loss: 5.5013 - y2_output_loss: 7.9501 - y1_output_root_mean_squared_error: 2.3347 - y2_output_root_mean_squared_error: 2.8273 - val_loss: 13.1285 - val_y1_output_loss: 4.4366 - val_y2_output_loss: 8.2713 - val_y1_output_root_mean_squared_error: 2.1394 - val_y2_output_root_mean_squared_error: 2.9243
# Epoch 20/500
# 614/614 [==============================] - 0s 143us/sample - loss: 14.1219 - y1_output_loss: 5.4123 - y2_output_loss: 8.6898 - y1_output_root_mean_squared_error: 2.3251 - y2_output_root_mean_squared_error: 2.9523 - val_loss: 11.8727 - val_y1_output_loss: 4.7273 - val_y2_output_loss: 7.1522 - val_y1_output_root_mean_squared_error: 2.1475 - val_y2_output_root_mean_squared_error: 2.6946
# Epoch 21/500
# 614/614 [==============================] - 0s 148us/sample - loss: 16.5716 - y1_output_loss: 5.7888 - y2_output_loss: 10.6831 - y1_output_root_mean_squared_error: 2.4084 - y2_output_root_mean_squared_error: 3.2819 - val_loss: 13.3550 - val_y1_output_loss: 3.9593 - val_y2_output_loss: 8.9690 - val_y1_output_root_mean_squared_error: 2.0164 - val_y2_output_root_mean_squared_error: 3.0478
# Epoch 22/500
# 614/614 [==============================] - 0s 143us/sample - loss: 16.7309 - y1_output_loss: 5.6027 - y2_output_loss: 11.0357 - y1_output_root_mean_squared_error: 2.3752 - y2_output_root_mean_squared_error: 3.3301 - val_loss: 14.7386 - val_y1_output_loss: 5.7180 - val_y2_output_loss: 8.9552 - val_y1_output_root_mean_squared_error: 2.3868 - val_y2_output_root_mean_squared_error: 3.0070
# Epoch 23/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.7642 - y1_output_loss: 4.5347 - y2_output_loss: 7.4901 - y1_output_root_mean_squared_error: 2.1316 - y2_output_root_mean_squared_error: 2.6871 - val_loss: 20.2188 - val_y1_output_loss: 6.1977 - val_y2_output_loss: 13.9050 - val_y1_output_root_mean_squared_error: 2.4870 - val_y2_output_root_mean_squared_error: 3.7462
# Epoch 24/500
# 614/614 [==============================] - 0s 142us/sample - loss: 13.1946 - y1_output_loss: 4.7388 - y2_output_loss: 8.3897 - y1_output_root_mean_squared_error: 2.1823 - y2_output_root_mean_squared_error: 2.9039 - val_loss: 13.0171 - val_y1_output_loss: 4.2757 - val_y2_output_loss: 8.3649 - val_y1_output_root_mean_squared_error: 2.0935 - val_y2_output_root_mean_squared_error: 2.9384
# Epoch 25/500
# 614/614 [==============================] - 0s 145us/sample - loss: 11.3908 - y1_output_loss: 4.3733 - y2_output_loss: 6.9393 - y1_output_root_mean_squared_error: 2.0959 - y2_output_root_mean_squared_error: 2.6453 - val_loss: 8.7048 - val_y1_output_loss: 3.4004 - val_y2_output_loss: 5.2459 - val_y1_output_root_mean_squared_error: 1.8350 - val_y2_output_root_mean_squared_error: 2.3103
# Epoch 26/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.1662 - y1_output_loss: 3.8331 - y2_output_loss: 6.3167 - y1_output_root_mean_squared_error: 1.9508 - y2_output_root_mean_squared_error: 2.5220 - val_loss: 12.1845 - val_y1_output_loss: 4.3653 - val_y2_output_loss: 7.6108 - val_y1_output_root_mean_squared_error: 2.0984 - val_y2_output_root_mean_squared_error: 2.7895
# Epoch 27/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.5186 - y1_output_loss: 3.5929 - y2_output_loss: 6.8356 - y1_output_root_mean_squared_error: 1.9042 - y2_output_root_mean_squared_error: 2.6254 - val_loss: 8.3003 - val_y1_output_loss: 2.8884 - val_y2_output_loss: 5.3320 - val_y1_output_root_mean_squared_error: 1.6881 - val_y2_output_root_mean_squared_error: 2.3347
# Epoch 28/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.8486 - y1_output_loss: 3.5366 - y2_output_loss: 6.3207 - y1_output_root_mean_squared_error: 1.8689 - y2_output_root_mean_squared_error: 2.5211 - val_loss: 16.3105 - val_y1_output_loss: 5.8050 - val_y2_output_loss: 9.9566 - val_y1_output_root_mean_squared_error: 2.4527 - val_y2_output_root_mean_squared_error: 3.2085
# Epoch 29/500
# 614/614 [==============================] - 0s 146us/sample - loss: 17.3816 - y1_output_loss: 5.6728 - y2_output_loss: 11.6389 - y1_output_root_mean_squared_error: 2.3851 - y2_output_root_mean_squared_error: 3.4195 - val_loss: 11.6567 - val_y1_output_loss: 2.7664 - val_y2_output_loss: 8.6011 - val_y1_output_root_mean_squared_error: 1.6610 - val_y2_output_root_mean_squared_error: 2.9829
# Epoch 30/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.2296 - y1_output_loss: 3.3913 - y2_output_loss: 6.7845 - y1_output_root_mean_squared_error: 1.8414 - y2_output_root_mean_squared_error: 2.6151 - val_loss: 9.5654 - val_y1_output_loss: 2.9604 - val_y2_output_loss: 6.3813 - val_y1_output_root_mean_squared_error: 1.7253 - val_y2_output_root_mean_squared_error: 2.5668
# Epoch 31/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.3378 - y1_output_loss: 3.5897 - y2_output_loss: 6.7465 - y1_output_root_mean_squared_error: 1.8871 - y2_output_root_mean_squared_error: 2.6032 - val_loss: 9.0513 - val_y1_output_loss: 2.9009 - val_y2_output_loss: 5.8538 - val_y1_output_root_mean_squared_error: 1.7321 - val_y2_output_root_mean_squared_error: 2.4599
# Epoch 32/500
# 614/614 [==============================] - 0s 149us/sample - loss: 8.4764 - y1_output_loss: 2.9977 - y2_output_loss: 5.4591 - y1_output_root_mean_squared_error: 1.7361 - y2_output_root_mean_squared_error: 2.3372 - val_loss: 8.2284 - val_y1_output_loss: 3.3151 - val_y2_output_loss: 5.0619 - val_y1_output_root_mean_squared_error: 1.7870 - val_y2_output_root_mean_squared_error: 2.2439
# Epoch 33/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.3812 - y1_output_loss: 3.2498 - y2_output_loss: 7.0677 - y1_output_root_mean_squared_error: 1.8056 - y2_output_root_mean_squared_error: 2.6685 - val_loss: 7.7644 - val_y1_output_loss: 3.0507 - val_y2_output_loss: 4.8754 - val_y1_output_root_mean_squared_error: 1.6994 - val_y2_output_root_mean_squared_error: 2.2083
# Epoch 34/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.4997 - y1_output_loss: 2.8400 - y2_output_loss: 5.7675 - y1_output_root_mean_squared_error: 1.6892 - y2_output_root_mean_squared_error: 2.3762 - val_loss: 12.0317 - val_y1_output_loss: 3.0421 - val_y2_output_loss: 8.5977 - val_y1_output_root_mean_squared_error: 1.7715 - val_y2_output_root_mean_squared_error: 2.9822
# Epoch 35/500
# 614/614 [==============================] - 0s 146us/sample - loss: 20.0926 - y1_output_loss: 6.4320 - y2_output_loss: 13.5140 - y1_output_root_mean_squared_error: 2.5405 - y2_output_root_mean_squared_error: 3.6930 - val_loss: 12.3852 - val_y1_output_loss: 2.7115 - val_y2_output_loss: 9.3344 - val_y1_output_root_mean_squared_error: 1.6495 - val_y2_output_root_mean_squared_error: 3.1088
# Epoch 36/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.7300 - y1_output_loss: 2.8377 - y2_output_loss: 5.9981 - y1_output_root_mean_squared_error: 1.6843 - y2_output_root_mean_squared_error: 2.4276 - val_loss: 6.4807 - val_y1_output_loss: 2.3088 - val_y2_output_loss: 4.2123 - val_y1_output_root_mean_squared_error: 1.5007 - val_y2_output_root_mean_squared_error: 2.0564
# Epoch 37/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.1491 - y1_output_loss: 2.7829 - y2_output_loss: 5.4744 - y1_output_root_mean_squared_error: 1.6655 - y2_output_root_mean_squared_error: 2.3184 - val_loss: 18.2100 - val_y1_output_loss: 5.8596 - val_y2_output_loss: 12.7166 - val_y1_output_root_mean_squared_error: 2.3792 - val_y2_output_root_mean_squared_error: 3.5425
# Epoch 38/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.0859 - y1_output_loss: 2.6024 - y2_output_loss: 5.4706 - y1_output_root_mean_squared_error: 1.6178 - y2_output_root_mean_squared_error: 2.3385 - val_loss: 11.2268 - val_y1_output_loss: 3.4054 - val_y2_output_loss: 7.8097 - val_y1_output_root_mean_squared_error: 1.8337 - val_y2_output_root_mean_squared_error: 2.8043
# Epoch 39/500
# 614/614 [==============================] - 0s 170us/sample - loss: 9.8170 - y1_output_loss: 3.0075 - y2_output_loss: 6.7206 - y1_output_root_mean_squared_error: 1.7414 - y2_output_root_mean_squared_error: 2.6047 - val_loss: 11.7486 - val_y1_output_loss: 3.7599 - val_y2_output_loss: 7.8060 - val_y1_output_root_mean_squared_error: 1.9339 - val_y2_output_root_mean_squared_error: 2.8300
# Epoch 40/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.8290 - y1_output_loss: 2.6083 - y2_output_loss: 5.2467 - y1_output_root_mean_squared_error: 1.6094 - y2_output_root_mean_squared_error: 2.2889 - val_loss: 21.4932 - val_y1_output_loss: 6.3309 - val_y2_output_loss: 14.4196 - val_y1_output_root_mean_squared_error: 2.5561 - val_y2_output_root_mean_squared_error: 3.8677
# Epoch 41/500
# 614/614 [==============================] - 0s 157us/sample - loss: 13.7548 - y1_output_loss: 4.3148 - y2_output_loss: 9.3268 - y1_output_root_mean_squared_error: 2.0851 - y2_output_root_mean_squared_error: 3.0671 - val_loss: 7.9338 - val_y1_output_loss: 2.6186 - val_y2_output_loss: 5.2886 - val_y1_output_root_mean_squared_error: 1.5920 - val_y2_output_root_mean_squared_error: 2.3236
# Epoch 42/500
# 614/614 [==============================] - 0s 176us/sample - loss: 8.5845 - y1_output_loss: 2.5666 - y2_output_loss: 5.9508 - y1_output_root_mean_squared_error: 1.6057 - y2_output_root_mean_squared_error: 2.4508 - val_loss: 6.7906 - val_y1_output_loss: 2.3481 - val_y2_output_loss: 4.4718 - val_y1_output_root_mean_squared_error: 1.5081 - val_y2_output_root_mean_squared_error: 2.1252
# Epoch 43/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.0838 - y1_output_loss: 2.5255 - y2_output_loss: 5.4947 - y1_output_root_mean_squared_error: 1.5944 - y2_output_root_mean_squared_error: 2.3541 - val_loss: 10.9340 - val_y1_output_loss: 2.8128 - val_y2_output_loss: 7.8772 - val_y1_output_root_mean_squared_error: 1.6781 - val_y2_output_root_mean_squared_error: 2.8492
# Epoch 44/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.8572 - y1_output_loss: 2.5977 - y2_output_loss: 5.5035 - y1_output_root_mean_squared_error: 1.5869 - y2_output_root_mean_squared_error: 2.3106 - val_loss: 46.2967 - val_y1_output_loss: 13.6942 - val_y2_output_loss: 32.0329 - val_y1_output_root_mean_squared_error: 3.7141 - val_y2_output_root_mean_squared_error: 5.7011
# Epoch 45/500
# 614/614 [==============================] - 0s 149us/sample - loss: 13.0601 - y1_output_loss: 3.7278 - y2_output_loss: 9.3001 - y1_output_root_mean_squared_error: 1.9302 - y2_output_root_mean_squared_error: 3.0552 - val_loss: 6.6324 - val_y1_output_loss: 2.5791 - val_y2_output_loss: 4.0627 - val_y1_output_root_mean_squared_error: 1.5913 - val_y2_output_root_mean_squared_error: 2.0249
# Epoch 46/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.8230 - y1_output_loss: 2.5451 - y2_output_loss: 5.2133 - y1_output_root_mean_squared_error: 1.6006 - y2_output_root_mean_squared_error: 2.2937 - val_loss: 6.1426 - val_y1_output_loss: 2.1067 - val_y2_output_loss: 4.0170 - val_y1_output_root_mean_squared_error: 1.4380 - val_y2_output_root_mean_squared_error: 2.0186
# Epoch 47/500
# 614/614 [==============================] - 0s 150us/sample - loss: 6.6058 - y1_output_loss: 2.1767 - y2_output_loss: 4.4256 - y1_output_root_mean_squared_error: 1.4776 - y2_output_root_mean_squared_error: 2.1030 - val_loss: 9.8240 - val_y1_output_loss: 3.3613 - val_y2_output_loss: 6.4472 - val_y1_output_root_mean_squared_error: 1.8245 - val_y2_output_root_mean_squared_error: 2.5486
# Epoch 48/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.2583 - y1_output_loss: 2.3737 - y2_output_loss: 4.8332 - y1_output_root_mean_squared_error: 1.5434 - y2_output_root_mean_squared_error: 2.2082 - val_loss: 6.3030 - val_y1_output_loss: 2.3054 - val_y2_output_loss: 3.8679 - val_y1_output_root_mean_squared_error: 1.5327 - val_y2_output_root_mean_squared_error: 1.9885
# Epoch 49/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.0715 - y1_output_loss: 2.6603 - y2_output_loss: 5.4200 - y1_output_root_mean_squared_error: 1.6172 - y2_output_root_mean_squared_error: 2.3358 - val_loss: 7.1847 - val_y1_output_loss: 2.4437 - val_y2_output_loss: 4.5356 - val_y1_output_root_mean_squared_error: 1.5808 - val_y2_output_root_mean_squared_error: 2.1647
# Epoch 50/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.0500 - y1_output_loss: 2.3426 - y2_output_loss: 4.7461 - y1_output_root_mean_squared_error: 1.5125 - y2_output_root_mean_squared_error: 2.1823 - val_loss: 7.1924 - val_y1_output_loss: 3.0957 - val_y2_output_loss: 4.1988 - val_y1_output_root_mean_squared_error: 1.7235 - val_y2_output_root_mean_squared_error: 2.0547
# Epoch 51/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.0056 - y1_output_loss: 2.2299 - y2_output_loss: 4.7524 - y1_output_root_mean_squared_error: 1.4916 - y2_output_root_mean_squared_error: 2.1864 - val_loss: 6.8995 - val_y1_output_loss: 2.9871 - val_y2_output_loss: 4.0079 - val_y1_output_root_mean_squared_error: 1.6947 - val_y2_output_root_mean_squared_error: 2.0069
# Epoch 52/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.4023 - y1_output_loss: 2.0020 - y2_output_loss: 4.3521 - y1_output_root_mean_squared_error: 1.4187 - y2_output_root_mean_squared_error: 2.0951 - val_loss: 7.4417 - val_y1_output_loss: 2.3227 - val_y2_output_loss: 5.0402 - val_y1_output_root_mean_squared_error: 1.5196 - val_y2_output_root_mean_squared_error: 2.2655
# Epoch 53/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.7906 - y1_output_loss: 2.1585 - y2_output_loss: 4.6618 - y1_output_root_mean_squared_error: 1.4614 - y2_output_root_mean_squared_error: 2.1575 - val_loss: 6.9805 - val_y1_output_loss: 2.4558 - val_y2_output_loss: 4.6181 - val_y1_output_root_mean_squared_error: 1.5320 - val_y2_output_root_mean_squared_error: 2.1525
# Epoch 54/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.2047 - y1_output_loss: 1.9668 - y2_output_loss: 4.1879 - y1_output_root_mean_squared_error: 1.4075 - y2_output_root_mean_squared_error: 2.0551 - val_loss: 5.7691 - val_y1_output_loss: 1.9072 - val_y2_output_loss: 3.9084 - val_y1_output_root_mean_squared_error: 1.3555 - val_y2_output_root_mean_squared_error: 1.9828
# Epoch 55/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.4056 - y1_output_loss: 2.3557 - y2_output_loss: 5.0176 - y1_output_root_mean_squared_error: 1.5312 - y2_output_root_mean_squared_error: 2.2497 - val_loss: 6.9114 - val_y1_output_loss: 1.9287 - val_y2_output_loss: 4.8764 - val_y1_output_root_mean_squared_error: 1.3806 - val_y2_output_root_mean_squared_error: 2.2373
# Epoch 56/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.4174 - y1_output_loss: 2.2298 - y2_output_loss: 5.1739 - y1_output_root_mean_squared_error: 1.4963 - y2_output_root_mean_squared_error: 2.2756 - val_loss: 14.8114 - val_y1_output_loss: 2.8943 - val_y2_output_loss: 11.4543 - val_y1_output_root_mean_squared_error: 1.7172 - val_y2_output_root_mean_squared_error: 3.4442
# Epoch 57/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.7419 - y1_output_loss: 1.8440 - y2_output_loss: 3.8519 - y1_output_root_mean_squared_error: 1.3632 - y2_output_root_mean_squared_error: 1.9707 - val_loss: 12.0440 - val_y1_output_loss: 2.8957 - val_y2_output_loss: 8.7871 - val_y1_output_root_mean_squared_error: 1.7167 - val_y2_output_root_mean_squared_error: 3.0161
# Epoch 58/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.4997 - y1_output_loss: 2.0054 - y2_output_loss: 4.4882 - y1_output_root_mean_squared_error: 1.4067 - y2_output_root_mean_squared_error: 2.1262 - val_loss: 7.2655 - val_y1_output_loss: 3.1234 - val_y2_output_loss: 4.4658 - val_y1_output_root_mean_squared_error: 1.7135 - val_y2_output_root_mean_squared_error: 2.0807
# Epoch 59/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.5809 - y1_output_loss: 1.7722 - y2_output_loss: 3.8258 - y1_output_root_mean_squared_error: 1.3283 - y2_output_root_mean_squared_error: 1.9536 - val_loss: 12.0277 - val_y1_output_loss: 3.2843 - val_y2_output_loss: 9.0167 - val_y1_output_root_mean_squared_error: 1.7753 - val_y2_output_root_mean_squared_error: 2.9793
# Epoch 60/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.7334 - y1_output_loss: 2.1234 - y2_output_loss: 4.8139 - y1_output_root_mean_squared_error: 1.4251 - y2_output_root_mean_squared_error: 2.1685 - val_loss: 46.2072 - val_y1_output_loss: 15.4722 - val_y2_output_loss: 29.0560 - val_y1_output_root_mean_squared_error: 4.0080 - val_y2_output_root_mean_squared_error: 5.4903
# Epoch 61/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.0176 - y1_output_loss: 2.0500 - y2_output_loss: 3.9312 - y1_output_root_mean_squared_error: 1.4348 - y2_output_root_mean_squared_error: 1.9897 - val_loss: 5.6407 - val_y1_output_loss: 2.0113 - val_y2_output_loss: 3.5520 - val_y1_output_root_mean_squared_error: 1.4215 - val_y2_output_root_mean_squared_error: 1.9026
# Epoch 62/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.0313 - y1_output_loss: 1.7890 - y2_output_loss: 4.1924 - y1_output_root_mean_squared_error: 1.3419 - y2_output_root_mean_squared_error: 2.0568 - val_loss: 4.8553 - val_y1_output_loss: 1.9058 - val_y2_output_loss: 3.0465 - val_y1_output_root_mean_squared_error: 1.3544 - val_y2_output_root_mean_squared_error: 1.7381
# Epoch 63/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.4686 - y1_output_loss: 1.9165 - y2_output_loss: 4.6068 - y1_output_root_mean_squared_error: 1.3802 - y2_output_root_mean_squared_error: 2.1363 - val_loss: 7.9053 - val_y1_output_loss: 1.4003 - val_y2_output_loss: 6.3363 - val_y1_output_root_mean_squared_error: 1.1731 - val_y2_output_root_mean_squared_error: 2.5552
# Epoch 64/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.9766 - y1_output_loss: 1.6757 - y2_output_loss: 4.2872 - y1_output_root_mean_squared_error: 1.2971 - y2_output_root_mean_squared_error: 2.0722 - val_loss: 4.2376 - val_y1_output_loss: 1.3076 - val_y2_output_loss: 3.0395 - val_y1_output_root_mean_squared_error: 1.1194 - val_y2_output_root_mean_squared_error: 1.7276
# Epoch 65/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.1102 - y1_output_loss: 1.7073 - y2_output_loss: 4.3885 - y1_output_root_mean_squared_error: 1.3034 - y2_output_root_mean_squared_error: 2.1003 - val_loss: 5.1407 - val_y1_output_loss: 1.3799 - val_y2_output_loss: 3.6513 - val_y1_output_root_mean_squared_error: 1.1798 - val_y2_output_root_mean_squared_error: 1.9362
# Epoch 66/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.8419 - y1_output_loss: 1.4836 - y2_output_loss: 3.3249 - y1_output_root_mean_squared_error: 1.2212 - y2_output_root_mean_squared_error: 1.8304 - val_loss: 4.8807 - val_y1_output_loss: 1.1724 - val_y2_output_loss: 3.6513 - val_y1_output_root_mean_squared_error: 1.0710 - val_y2_output_root_mean_squared_error: 1.9323
# Epoch 67/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.8663 - y1_output_loss: 1.3448 - y2_output_loss: 3.4856 - y1_output_root_mean_squared_error: 1.1641 - y2_output_root_mean_squared_error: 1.8738 - val_loss: 4.5278 - val_y1_output_loss: 1.6415 - val_y2_output_loss: 3.0317 - val_y1_output_root_mean_squared_error: 1.2456 - val_y2_output_root_mean_squared_error: 1.7252
# Epoch 68/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.6404 - y1_output_loss: 1.4934 - y2_output_loss: 3.1383 - y1_output_root_mean_squared_error: 1.2230 - y2_output_root_mean_squared_error: 1.7733 - val_loss: 5.0858 - val_y1_output_loss: 1.5678 - val_y2_output_loss: 3.7706 - val_y1_output_root_mean_squared_error: 1.2110 - val_y2_output_root_mean_squared_error: 1.9025
# Epoch 69/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.8303 - y1_output_loss: 2.0879 - y2_output_loss: 4.7714 - y1_output_root_mean_squared_error: 1.4476 - y2_output_root_mean_squared_error: 2.1760 - val_loss: 5.1896 - val_y1_output_loss: 1.6866 - val_y2_output_loss: 3.6709 - val_y1_output_root_mean_squared_error: 1.2773 - val_y2_output_root_mean_squared_error: 1.8863
# Epoch 70/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.9973 - y1_output_loss: 1.4809 - y2_output_loss: 3.5011 - y1_output_root_mean_squared_error: 1.2221 - y2_output_root_mean_squared_error: 1.8718 - val_loss: 5.0586 - val_y1_output_loss: 1.9023 - val_y2_output_loss: 3.0475 - val_y1_output_root_mean_squared_error: 1.3998 - val_y2_output_root_mean_squared_error: 1.7604
# Epoch 71/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.5820 - y1_output_loss: 1.3934 - y2_output_loss: 3.1481 - y1_output_root_mean_squared_error: 1.1849 - y2_output_root_mean_squared_error: 1.7827 - val_loss: 4.3637 - val_y1_output_loss: 1.2008 - val_y2_output_loss: 3.1043 - val_y1_output_root_mean_squared_error: 1.1042 - val_y2_output_root_mean_squared_error: 1.7732
# Epoch 72/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.8537 - y1_output_loss: 1.0220 - y2_output_loss: 2.7989 - y1_output_root_mean_squared_error: 1.0154 - y2_output_root_mean_squared_error: 1.6801 - val_loss: 3.8059 - val_y1_output_loss: 0.9782 - val_y2_output_loss: 2.8044 - val_y1_output_root_mean_squared_error: 0.9756 - val_y2_output_root_mean_squared_error: 1.6894
# Epoch 73/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.7150 - y1_output_loss: 1.1552 - y2_output_loss: 3.5156 - y1_output_root_mean_squared_error: 1.0798 - y2_output_root_mean_squared_error: 1.8839 - val_loss: 3.3148 - val_y1_output_loss: 1.0214 - val_y2_output_loss: 2.2520 - val_y1_output_root_mean_squared_error: 1.0088 - val_y2_output_root_mean_squared_error: 1.5156
# Epoch 74/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.6141 - y1_output_loss: 0.9743 - y2_output_loss: 2.6096 - y1_output_root_mean_squared_error: 0.9914 - y2_output_root_mean_squared_error: 1.6221 - val_loss: 3.1054 - val_y1_output_loss: 1.0003 - val_y2_output_loss: 2.1205 - val_y1_output_root_mean_squared_error: 0.9891 - val_y2_output_root_mean_squared_error: 1.4584
# Epoch 75/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.5658 - y1_output_loss: 1.0064 - y2_output_loss: 2.7496 - y1_output_root_mean_squared_error: 0.9851 - y2_output_root_mean_squared_error: 1.6110 - val_loss: 20.6272 - val_y1_output_loss: 5.8724 - val_y2_output_loss: 15.5660 - val_y1_output_root_mean_squared_error: 2.3617 - val_y2_output_root_mean_squared_error: 3.8794
# Epoch 76/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.9898 - y1_output_loss: 1.1536 - y2_output_loss: 2.8411 - y1_output_root_mean_squared_error: 1.0752 - y2_output_root_mean_squared_error: 1.6834 - val_loss: 2.7376 - val_y1_output_loss: 0.7470 - val_y2_output_loss: 2.0675 - val_y1_output_root_mean_squared_error: 0.8517 - val_y2_output_root_mean_squared_error: 1.4185
# Epoch 77/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.8562 - y1_output_loss: 1.7647 - y2_output_loss: 4.0385 - y1_output_root_mean_squared_error: 1.3344 - y2_output_root_mean_squared_error: 2.0188 - val_loss: 2.8342 - val_y1_output_loss: 0.8072 - val_y2_output_loss: 2.1228 - val_y1_output_root_mean_squared_error: 0.8828 - val_y2_output_root_mean_squared_error: 1.4334
# Epoch 78/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.8335 - y1_output_loss: 1.0398 - y2_output_loss: 2.7706 - y1_output_root_mean_squared_error: 1.0192 - y2_output_root_mean_squared_error: 1.6718 - val_loss: 4.1193 - val_y1_output_loss: 1.2389 - val_y2_output_loss: 2.8572 - val_y1_output_root_mean_squared_error: 1.1011 - val_y2_output_root_mean_squared_error: 1.7050
# Epoch 79/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.9290 - y1_output_loss: 0.9521 - y2_output_loss: 2.9547 - y1_output_root_mean_squared_error: 0.9795 - y2_output_root_mean_squared_error: 1.7233 - val_loss: 6.1981 - val_y1_output_loss: 0.9586 - val_y2_output_loss: 5.0499 - val_y1_output_root_mean_squared_error: 0.9873 - val_y2_output_root_mean_squared_error: 2.2854
# Epoch 80/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.3165 - y1_output_loss: 0.8759 - y2_output_loss: 2.5816 - y1_output_root_mean_squared_error: 0.9264 - y2_output_root_mean_squared_error: 1.5679 - val_loss: 39.7240 - val_y1_output_loss: 8.3460 - val_y2_output_loss: 30.4733 - val_y1_output_root_mean_squared_error: 2.9242 - val_y2_output_root_mean_squared_error: 5.5833
# Epoch 81/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.4626 - y1_output_loss: 2.3471 - y2_output_loss: 6.0825 - y1_output_root_mean_squared_error: 1.5361 - y2_output_root_mean_squared_error: 2.4704 - val_loss: 6.0414 - val_y1_output_loss: 1.0042 - val_y2_output_loss: 5.0229 - val_y1_output_root_mean_squared_error: 0.9584 - val_y2_output_root_mean_squared_error: 2.2634
# Epoch 82/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.2889 - y1_output_loss: 0.8643 - y2_output_loss: 2.4411 - y1_output_root_mean_squared_error: 0.9332 - y2_output_root_mean_squared_error: 1.5550 - val_loss: 2.5593 - val_y1_output_loss: 0.6421 - val_y2_output_loss: 1.9177 - val_y1_output_root_mean_squared_error: 0.7930 - val_y2_output_root_mean_squared_error: 1.3894
# Epoch 83/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3742 - y1_output_loss: 0.7978 - y2_output_loss: 2.5952 - y1_output_root_mean_squared_error: 0.8902 - y2_output_root_mean_squared_error: 1.6068 - val_loss: 7.2103 - val_y1_output_loss: 2.5296 - val_y2_output_loss: 4.7268 - val_y1_output_root_mean_squared_error: 1.5830 - val_y2_output_root_mean_squared_error: 2.1690
# Epoch 84/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.2314 - y1_output_loss: 0.8184 - y2_output_loss: 2.3919 - y1_output_root_mean_squared_error: 0.9044 - y2_output_root_mean_squared_error: 1.5535 - val_loss: 5.3746 - val_y1_output_loss: 0.8645 - val_y2_output_loss: 4.3615 - val_y1_output_root_mean_squared_error: 0.9388 - val_y2_output_root_mean_squared_error: 2.1197
# Epoch 85/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.2600 - y1_output_loss: 1.1398 - y2_output_loss: 3.0976 - y1_output_root_mean_squared_error: 1.0706 - y2_output_root_mean_squared_error: 1.7646 - val_loss: 3.5419 - val_y1_output_loss: 0.9084 - val_y2_output_loss: 2.6187 - val_y1_output_root_mean_squared_error: 0.9398 - val_y2_output_root_mean_squared_error: 1.6306
# Epoch 86/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.3729 - y1_output_loss: 1.0999 - y2_output_loss: 3.2631 - y1_output_root_mean_squared_error: 1.0480 - y2_output_root_mean_squared_error: 1.8096 - val_loss: 4.2309 - val_y1_output_loss: 0.7666 - val_y2_output_loss: 3.3801 - val_y1_output_root_mean_squared_error: 0.8733 - val_y2_output_root_mean_squared_error: 1.8623
# Epoch 87/500
# 614/614 [==============================] - 0s 146us/sample - loss: 12.3312 - y1_output_loss: 3.6088 - y2_output_loss: 8.6246 - y1_output_root_mean_squared_error: 1.9084 - y2_output_root_mean_squared_error: 2.9477 - val_loss: 2.8722 - val_y1_output_loss: 0.8655 - val_y2_output_loss: 1.9892 - val_y1_output_root_mean_squared_error: 0.9327 - val_y2_output_root_mean_squared_error: 1.4150
# Epoch 88/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0860 - y1_output_loss: 0.7186 - y2_output_loss: 2.3537 - y1_output_root_mean_squared_error: 0.8499 - y2_output_root_mean_squared_error: 1.5374 - val_loss: 2.2708 - val_y1_output_loss: 0.5575 - val_y2_output_loss: 1.7281 - val_y1_output_root_mean_squared_error: 0.7390 - val_y2_output_root_mean_squared_error: 1.3133
# Epoch 89/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.5807 - y1_output_loss: 0.9598 - y2_output_loss: 2.6134 - y1_output_root_mean_squared_error: 0.9840 - y2_output_root_mean_squared_error: 1.6163 - val_loss: 3.3475 - val_y1_output_loss: 1.2447 - val_y2_output_loss: 2.2551 - val_y1_output_root_mean_squared_error: 1.0918 - val_y2_output_root_mean_squared_error: 1.4681
# Epoch 90/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.1817 - y1_output_loss: 0.8249 - y2_output_loss: 2.3421 - y1_output_root_mean_squared_error: 0.9074 - y2_output_root_mean_squared_error: 1.5357 - val_loss: 2.2822 - val_y1_output_loss: 0.5369 - val_y2_output_loss: 1.7443 - val_y1_output_root_mean_squared_error: 0.7323 - val_y2_output_root_mean_squared_error: 1.3214
# Epoch 91/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.4474 - y1_output_loss: 0.8189 - y2_output_loss: 2.6256 - y1_output_root_mean_squared_error: 0.9087 - y2_output_root_mean_squared_error: 1.6191 - val_loss: 5.3327 - val_y1_output_loss: 1.2902 - val_y2_output_loss: 4.1741 - val_y1_output_root_mean_squared_error: 1.1202 - val_y2_output_root_mean_squared_error: 2.0194
# Epoch 92/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.1430 - y1_output_loss: 0.9572 - y2_output_loss: 3.1524 - y1_output_root_mean_squared_error: 0.9813 - y2_output_root_mean_squared_error: 1.7833 - val_loss: 1.9083 - val_y1_output_loss: 0.4644 - val_y2_output_loss: 1.4574 - val_y1_output_root_mean_squared_error: 0.6846 - val_y2_output_root_mean_squared_error: 1.1998
# Epoch 93/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.9663 - y1_output_loss: 0.6697 - y2_output_loss: 2.3299 - y1_output_root_mean_squared_error: 0.8178 - y2_output_root_mean_squared_error: 1.5157 - val_loss: 2.3530 - val_y1_output_loss: 0.5920 - val_y2_output_loss: 1.8482 - val_y1_output_root_mean_squared_error: 0.7423 - val_y2_output_root_mean_squared_error: 1.3424
# Epoch 94/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.7798 - y1_output_loss: 0.7073 - y2_output_loss: 2.0588 - y1_output_root_mean_squared_error: 0.8432 - y2_output_root_mean_squared_error: 1.4383 - val_loss: 2.2001 - val_y1_output_loss: 0.6383 - val_y2_output_loss: 1.5861 - val_y1_output_root_mean_squared_error: 0.7934 - val_y2_output_root_mean_squared_error: 1.2533
# Epoch 95/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.8701 - y1_output_loss: 0.8656 - y2_output_loss: 3.1579 - y1_output_root_mean_squared_error: 0.9133 - y2_output_root_mean_squared_error: 1.7424 - val_loss: 14.8124 - val_y1_output_loss: 5.1731 - val_y2_output_loss: 10.1983 - val_y1_output_root_mean_squared_error: 2.2396 - val_y2_output_root_mean_squared_error: 3.1299
# Epoch 96/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.0478 - y1_output_loss: 0.7557 - y2_output_loss: 2.2772 - y1_output_root_mean_squared_error: 0.8725 - y2_output_root_mean_squared_error: 1.5121 - val_loss: 2.9729 - val_y1_output_loss: 0.6312 - val_y2_output_loss: 2.3025 - val_y1_output_root_mean_squared_error: 0.7858 - val_y2_output_root_mean_squared_error: 1.5348
# Epoch 97/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.0533 - y1_output_loss: 1.0764 - y2_output_loss: 2.9657 - y1_output_root_mean_squared_error: 1.0385 - y2_output_root_mean_squared_error: 1.7248 - val_loss: 2.6054 - val_y1_output_loss: 0.5176 - val_y2_output_loss: 2.2128 - val_y1_output_root_mean_squared_error: 0.7101 - val_y2_output_root_mean_squared_error: 1.4496
# Epoch 98/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.8431 - y1_output_loss: 0.6395 - y2_output_loss: 2.1877 - y1_output_root_mean_squared_error: 0.8032 - y2_output_root_mean_squared_error: 1.4825 - val_loss: 3.3190 - val_y1_output_loss: 0.9481 - val_y2_output_loss: 2.3278 - val_y1_output_root_mean_squared_error: 0.9876 - val_y2_output_root_mean_squared_error: 1.5309
# Epoch 99/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.3277 - y1_output_loss: 0.7253 - y2_output_loss: 2.6246 - y1_output_root_mean_squared_error: 0.8525 - y2_output_root_mean_squared_error: 1.6128 - val_loss: 2.1536 - val_y1_output_loss: 0.6204 - val_y2_output_loss: 1.7103 - val_y1_output_root_mean_squared_error: 0.7607 - val_y2_output_root_mean_squared_error: 1.2549
# Epoch 100/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7046 - y1_output_loss: 0.6489 - y2_output_loss: 2.0453 - y1_output_root_mean_squared_error: 0.8053 - y2_output_root_mean_squared_error: 1.4339 - val_loss: 3.1413 - val_y1_output_loss: 0.9429 - val_y2_output_loss: 2.3552 - val_y1_output_root_mean_squared_error: 0.9466 - val_y2_output_root_mean_squared_error: 1.4984
# Epoch 101/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.4449 - y1_output_loss: 0.5679 - y2_output_loss: 1.8578 - y1_output_root_mean_squared_error: 0.7567 - y2_output_root_mean_squared_error: 1.3683 - val_loss: 2.0055 - val_y1_output_loss: 0.4223 - val_y2_output_loss: 1.6436 - val_y1_output_root_mean_squared_error: 0.6272 - val_y2_output_root_mean_squared_error: 1.2697
# Epoch 102/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9028 - y1_output_loss: 1.0991 - y2_output_loss: 2.7983 - y1_output_root_mean_squared_error: 1.0513 - y2_output_root_mean_squared_error: 1.6726 - val_loss: 3.2960 - val_y1_output_loss: 0.5597 - val_y2_output_loss: 2.8406 - val_y1_output_root_mean_squared_error: 0.7310 - val_y2_output_root_mean_squared_error: 1.6618
# Epoch 103/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.5293 - y1_output_loss: 0.5244 - y2_output_loss: 2.0376 - y1_output_root_mean_squared_error: 0.7262 - y2_output_root_mean_squared_error: 1.4149 - val_loss: 6.9414 - val_y1_output_loss: 1.4611 - val_y2_output_loss: 5.5852 - val_y1_output_root_mean_squared_error: 1.1969 - val_y2_output_root_mean_squared_error: 2.3471
# Epoch 104/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.9183 - y1_output_loss: 0.6555 - y2_output_loss: 2.2465 - y1_output_root_mean_squared_error: 0.8101 - y2_output_root_mean_squared_error: 1.5040 - val_loss: 1.9815 - val_y1_output_loss: 0.4678 - val_y2_output_loss: 1.4866 - val_y1_output_root_mean_squared_error: 0.6868 - val_y2_output_root_mean_squared_error: 1.2287
# Epoch 105/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.4326 - y1_output_loss: 0.7324 - y2_output_loss: 2.7968 - y1_output_root_mean_squared_error: 0.8415 - y2_output_root_mean_squared_error: 1.6506 - val_loss: 15.9609 - val_y1_output_loss: 5.3211 - val_y2_output_loss: 10.2895 - val_y1_output_root_mean_squared_error: 2.3404 - val_y2_output_root_mean_squared_error: 3.2378
# Epoch 106/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.6340 - y1_output_loss: 0.9854 - y2_output_loss: 2.6340 - y1_output_root_mean_squared_error: 0.9943 - y2_output_root_mean_squared_error: 1.6265 - val_loss: 3.5441 - val_y1_output_loss: 1.1263 - val_y2_output_loss: 2.3587 - val_y1_output_root_mean_squared_error: 1.0745 - val_y2_output_root_mean_squared_error: 1.5458
# Epoch 107/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.4044 - y1_output_loss: 0.5728 - y2_output_loss: 1.8566 - y1_output_root_mean_squared_error: 0.7597 - y2_output_root_mean_squared_error: 1.3518 - val_loss: 3.2149 - val_y1_output_loss: 0.7060 - val_y2_output_loss: 2.4646 - val_y1_output_root_mean_squared_error: 0.8406 - val_y2_output_root_mean_squared_error: 1.5838
# Epoch 108/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4443 - y1_output_loss: 0.6200 - y2_output_loss: 1.8094 - y1_output_root_mean_squared_error: 0.7897 - y2_output_root_mean_squared_error: 1.3493 - val_loss: 2.1104 - val_y1_output_loss: 0.4251 - val_y2_output_loss: 1.6617 - val_y1_output_root_mean_squared_error: 0.6550 - val_y2_output_root_mean_squared_error: 1.2966
# Epoch 109/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.4598 - y1_output_loss: 0.8008 - y2_output_loss: 2.6331 - y1_output_root_mean_squared_error: 0.8977 - y2_output_root_mean_squared_error: 1.6291 - val_loss: 1.9480 - val_y1_output_loss: 0.3594 - val_y2_output_loss: 1.5791 - val_y1_output_root_mean_squared_error: 0.6013 - val_y2_output_root_mean_squared_error: 1.2595
# Epoch 110/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.5061 - y1_output_loss: 0.6092 - y2_output_loss: 1.8867 - y1_output_root_mean_squared_error: 0.7786 - y2_output_root_mean_squared_error: 1.3783 - val_loss: 2.1101 - val_y1_output_loss: 0.3577 - val_y2_output_loss: 1.7366 - val_y1_output_root_mean_squared_error: 0.5991 - val_y2_output_root_mean_squared_error: 1.3233
# Epoch 111/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.3236 - y1_output_loss: 0.5103 - y2_output_loss: 1.7930 - y1_output_root_mean_squared_error: 0.7175 - y2_output_root_mean_squared_error: 1.3449 - val_loss: 2.0413 - val_y1_output_loss: 0.4376 - val_y2_output_loss: 1.6433 - val_y1_output_root_mean_squared_error: 0.6467 - val_y2_output_root_mean_squared_error: 1.2740
# Epoch 112/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.2216 - y1_output_loss: 0.4767 - y2_output_loss: 1.7555 - y1_output_root_mean_squared_error: 0.6922 - y2_output_root_mean_squared_error: 1.3200 - val_loss: 2.9824 - val_y1_output_loss: 0.3634 - val_y2_output_loss: 2.5860 - val_y1_output_root_mean_squared_error: 0.5941 - val_y2_output_root_mean_squared_error: 1.6216
# Epoch 113/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.5319 - y1_output_loss: 0.5370 - y2_output_loss: 1.9849 - y1_output_root_mean_squared_error: 0.7334 - y2_output_root_mean_squared_error: 1.4121 - val_loss: 3.5509 - val_y1_output_loss: 0.8264 - val_y2_output_loss: 2.6897 - val_y1_output_root_mean_squared_error: 0.9126 - val_y2_output_root_mean_squared_error: 1.6486
# Epoch 114/500
# 614/614 [==============================] - 0s 147us/sample - loss: 1.9509 - y1_output_loss: 0.5022 - y2_output_loss: 1.4664 - y1_output_root_mean_squared_error: 0.6985 - y2_output_root_mean_squared_error: 1.2095 - val_loss: 4.4210 - val_y1_output_loss: 0.4012 - val_y2_output_loss: 3.8898 - val_y1_output_root_mean_squared_error: 0.6331 - val_y2_output_root_mean_squared_error: 2.0050
# Epoch 115/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.9448 - y1_output_loss: 0.7199 - y2_output_loss: 2.2080 - y1_output_root_mean_squared_error: 0.8494 - y2_output_root_mean_squared_error: 1.4911 - val_loss: 1.8280 - val_y1_output_loss: 0.4938 - val_y2_output_loss: 1.4465 - val_y1_output_root_mean_squared_error: 0.6850 - val_y2_output_root_mean_squared_error: 1.1657
# Epoch 116/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.9088 - y1_output_loss: 0.6070 - y2_output_loss: 2.2966 - y1_output_root_mean_squared_error: 0.7749 - y2_output_root_mean_squared_error: 1.5193 - val_loss: 7.8550 - val_y1_output_loss: 2.0668 - val_y2_output_loss: 5.5308 - val_y1_output_root_mean_squared_error: 1.4584 - val_y2_output_root_mean_squared_error: 2.3933
# Epoch 117/500
# 614/614 [==============================] - 0s 202us/sample - loss: 6.0540 - y1_output_loss: 1.5266 - y2_output_loss: 4.5151 - y1_output_root_mean_squared_error: 1.2378 - y2_output_root_mean_squared_error: 2.1265 - val_loss: 10.3900 - val_y1_output_loss: 2.1036 - val_y2_output_loss: 7.9645 - val_y1_output_root_mean_squared_error: 1.4722 - val_y2_output_root_mean_squared_error: 2.8675
# Epoch 118/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.4326 - y1_output_loss: 0.5134 - y2_output_loss: 1.9060 - y1_output_root_mean_squared_error: 0.7155 - y2_output_root_mean_squared_error: 1.3859 - val_loss: 2.7598 - val_y1_output_loss: 0.7922 - val_y2_output_loss: 2.1209 - val_y1_output_root_mean_squared_error: 0.8792 - val_y2_output_root_mean_squared_error: 1.4095
# Epoch 119/500
# 614/614 [==============================] - 0s 147us/sample - loss: 1.7460 - y1_output_loss: 0.4468 - y2_output_loss: 1.2969 - y1_output_root_mean_squared_error: 0.6680 - y2_output_root_mean_squared_error: 1.1401 - val_loss: 1.9194 - val_y1_output_loss: 0.3534 - val_y2_output_loss: 1.5689 - val_y1_output_root_mean_squared_error: 0.6004 - val_y2_output_root_mean_squared_error: 1.2486
# Epoch 120/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.1220 - y1_output_loss: 0.4318 - y2_output_loss: 1.6713 - y1_output_root_mean_squared_error: 0.6593 - y2_output_root_mean_squared_error: 1.2990 - val_loss: 1.9166 - val_y1_output_loss: 0.4379 - val_y2_output_loss: 1.5102 - val_y1_output_root_mean_squared_error: 0.6509 - val_y2_output_root_mean_squared_error: 1.2219
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3556 - y1_output_loss: 0.1124 - y2_output_loss: 0.2402 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.4921 - val_loss: 0.7195 - val_y1_output_loss: 0.1406 - val_y2_output_loss: 0.5795 - val_y1_output_root_mean_squared_error: 0.3791 - val_y2_output_root_mean_squared_error: 0.7588
# Epoch 462/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4034 - y1_output_loss: 0.1221 - y2_output_loss: 0.2803 - y1_output_root_mean_squared_error: 0.3484 - y2_output_root_mean_squared_error: 0.5310 - val_loss: 0.8580 - val_y1_output_loss: 0.2580 - val_y2_output_loss: 0.6120 - val_y1_output_root_mean_squared_error: 0.5100 - val_y2_output_root_mean_squared_error: 0.7732
# Epoch 463/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4145 - y1_output_loss: 0.1311 - y2_output_loss: 0.2815 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.5316 - val_loss: 0.6498 - val_y1_output_loss: 0.1166 - val_y2_output_loss: 0.5287 - val_y1_output_root_mean_squared_error: 0.3462 - val_y2_output_root_mean_squared_error: 0.7280
# Epoch 464/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5546 - y1_output_loss: 0.1658 - y2_output_loss: 0.3851 - y1_output_root_mean_squared_error: 0.4089 - y2_output_root_mean_squared_error: 0.6224 - val_loss: 0.6986 - val_y1_output_loss: 0.1448 - val_y2_output_loss: 0.5442 - val_y1_output_root_mean_squared_error: 0.3843 - val_y2_output_root_mean_squared_error: 0.7422
# Epoch 465/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4188 - y1_output_loss: 0.1299 - y2_output_loss: 0.2892 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5369 - val_loss: 0.8082 - val_y1_output_loss: 0.1962 - val_y2_output_loss: 0.6332 - val_y1_output_root_mean_squared_error: 0.4459 - val_y2_output_root_mean_squared_error: 0.7807
# Epoch 466/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3635 - y1_output_loss: 0.1282 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.4862 - val_loss: 0.6245 - val_y1_output_loss: 0.1815 - val_y2_output_loss: 0.4363 - val_y1_output_root_mean_squared_error: 0.4323 - val_y2_output_root_mean_squared_error: 0.6616
# Epoch 467/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3786 - y1_output_loss: 0.1280 - y2_output_loss: 0.2531 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5005 - val_loss: 0.7940 - val_y1_output_loss: 0.1657 - val_y2_output_loss: 0.6225 - val_y1_output_root_mean_squared_error: 0.4120 - val_y2_output_root_mean_squared_error: 0.7901
# Epoch 468/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5572 - y1_output_loss: 0.1599 - y2_output_loss: 0.3948 - y1_output_root_mean_squared_error: 0.4010 - y2_output_root_mean_squared_error: 0.6296 - val_loss: 0.6593 - val_y1_output_loss: 0.1390 - val_y2_output_loss: 0.5159 - val_y1_output_root_mean_squared_error: 0.3772 - val_y2_output_root_mean_squared_error: 0.7191
# Epoch 469/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3350 - y1_output_loss: 0.1152 - y2_output_loss: 0.2205 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.4696 - val_loss: 0.8175 - val_y1_output_loss: 0.1126 - val_y2_output_loss: 0.7205 - val_y1_output_root_mean_squared_error: 0.3398 - val_y2_output_root_mean_squared_error: 0.8379
# Epoch 470/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3249 - y1_output_loss: 0.1123 - y2_output_loss: 0.2112 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.4614 - val_loss: 0.5540 - val_y1_output_loss: 0.1335 - val_y2_output_loss: 0.4184 - val_y1_output_root_mean_squared_error: 0.3697 - val_y2_output_root_mean_squared_error: 0.6460
# Epoch 471/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3280 - y1_output_loss: 0.1201 - y2_output_loss: 0.2099 - y1_output_root_mean_squared_error: 0.3476 - y2_output_root_mean_squared_error: 0.4551 - val_loss: 0.8293 - val_y1_output_loss: 0.2267 - val_y2_output_loss: 0.6122 - val_y1_output_root_mean_squared_error: 0.4794 - val_y2_output_root_mean_squared_error: 0.7743
# Epoch 472/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3173 - y1_output_loss: 0.1116 - y2_output_loss: 0.2055 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.4542 - val_loss: 0.8165 - val_y1_output_loss: 0.1254 - val_y2_output_loss: 0.6760 - val_y1_output_root_mean_squared_error: 0.3582 - val_y2_output_root_mean_squared_error: 0.8296
# Epoch 473/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3419 - y1_output_loss: 0.1125 - y2_output_loss: 0.2374 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.4780 - val_loss: 3.6619 - val_y1_output_loss: 0.3083 - val_y2_output_loss: 3.3071 - val_y1_output_root_mean_squared_error: 0.5616 - val_y2_output_root_mean_squared_error: 1.8293
# Epoch 474/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5163 - y1_output_loss: 0.1345 - y2_output_loss: 0.3774 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.6171 - val_loss: 0.5977 - val_y1_output_loss: 0.1487 - val_y2_output_loss: 0.4515 - val_y1_output_root_mean_squared_error: 0.3854 - val_y2_output_root_mean_squared_error: 0.6702
# Epoch 475/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4563 - y1_output_loss: 0.1350 - y2_output_loss: 0.3184 - y1_output_root_mean_squared_error: 0.3689 - y2_output_root_mean_squared_error: 0.5659 - val_loss: 0.5298 - val_y1_output_loss: 0.1194 - val_y2_output_loss: 0.4079 - val_y1_output_root_mean_squared_error: 0.3497 - val_y2_output_root_mean_squared_error: 0.6384
# Epoch 476/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4305 - y1_output_loss: 0.1443 - y2_output_loss: 0.2839 - y1_output_root_mean_squared_error: 0.3802 - y2_output_root_mean_squared_error: 0.5347 - val_loss: 0.7113 - val_y1_output_loss: 0.1853 - val_y2_output_loss: 0.5217 - val_y1_output_root_mean_squared_error: 0.4294 - val_y2_output_root_mean_squared_error: 0.7259
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4335 - y1_output_loss: 0.1316 - y2_output_loss: 0.3046 - y1_output_root_mean_squared_error: 0.3643 - y2_output_root_mean_squared_error: 0.5485 - val_loss: 0.7297 - val_y1_output_loss: 0.1288 - val_y2_output_loss: 0.5910 - val_y1_output_root_mean_squared_error: 0.3635 - val_y2_output_root_mean_squared_error: 0.7730
# Epoch 478/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3877 - y1_output_loss: 0.1273 - y2_output_loss: 0.2611 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5096 - val_loss: 0.6499 - val_y1_output_loss: 0.1846 - val_y2_output_loss: 0.4591 - val_y1_output_root_mean_squared_error: 0.4347 - val_y2_output_root_mean_squared_error: 0.6789
# Epoch 479/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3373 - y1_output_loss: 0.1164 - y2_output_loss: 0.2190 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.4697 - val_loss: 0.5784 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 0.4047 - val_y1_output_root_mean_squared_error: 0.4358 - val_y2_output_root_mean_squared_error: 0.6234
# Epoch 480/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3961 - y1_output_loss: 0.1347 - y2_output_loss: 0.2602 - y1_output_root_mean_squared_error: 0.3675 - y2_output_root_mean_squared_error: 0.5109 - val_loss: 0.5360 - val_y1_output_loss: 0.1042 - val_y2_output_loss: 0.4330 - val_y1_output_root_mean_squared_error: 0.3259 - val_y2_output_root_mean_squared_error: 0.6556
# Epoch 481/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2879 - y1_output_loss: 0.1081 - y2_output_loss: 0.1797 - y1_output_root_mean_squared_error: 0.3294 - y2_output_root_mean_squared_error: 0.4235 - val_loss: 0.6202 - val_y1_output_loss: 0.1387 - val_y2_output_loss: 0.4782 - val_y1_output_root_mean_squared_error: 0.3771 - val_y2_output_root_mean_squared_error: 0.6914
# Epoch 482/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3744 - y1_output_loss: 0.1189 - y2_output_loss: 0.2559 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.5065 - val_loss: 0.9875 - val_y1_output_loss: 0.2395 - val_y2_output_loss: 0.7276 - val_y1_output_root_mean_squared_error: 0.4968 - val_y2_output_root_mean_squared_error: 0.8606
# Epoch 483/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3659 - y1_output_loss: 0.1298 - y2_output_loss: 0.2343 - y1_output_root_mean_squared_error: 0.3607 - y2_output_root_mean_squared_error: 0.4856 - val_loss: 0.5962 - val_y1_output_loss: 0.1754 - val_y2_output_loss: 0.4183 - val_y1_output_root_mean_squared_error: 0.4232 - val_y2_output_root_mean_squared_error: 0.6459
# Epoch 484/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3280 - y1_output_loss: 0.1189 - y2_output_loss: 0.2099 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.4563 - val_loss: 1.4912 - val_y1_output_loss: 0.3420 - val_y2_output_loss: 1.1316 - val_y1_output_root_mean_squared_error: 0.5939 - val_y2_output_root_mean_squared_error: 1.0670
# Epoch 485/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.8034 - y1_output_loss: 0.1973 - y2_output_loss: 0.5996 - y1_output_root_mean_squared_error: 0.4453 - y2_output_root_mean_squared_error: 0.7779 - val_loss: 0.5787 - val_y1_output_loss: 0.1275 - val_y2_output_loss: 0.4490 - val_y1_output_root_mean_squared_error: 0.3576 - val_y2_output_root_mean_squared_error: 0.6714
# Epoch 486/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3438 - y1_output_loss: 0.1203 - y2_output_loss: 0.2227 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.4723 - val_loss: 1.6933 - val_y1_output_loss: 0.5641 - val_y2_output_loss: 1.1236 - val_y1_output_root_mean_squared_error: 0.7601 - val_y2_output_root_mean_squared_error: 1.0562
# Epoch 487/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3291 - y1_output_loss: 0.1303 - y2_output_loss: 0.1969 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.4453 - val_loss: 0.5807 - val_y1_output_loss: 0.1199 - val_y2_output_loss: 0.4631 - val_y1_output_root_mean_squared_error: 0.3505 - val_y2_output_root_mean_squared_error: 0.6766
# Epoch 488/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3413 - y1_output_loss: 0.1148 - y2_output_loss: 0.2242 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.4750 - val_loss: 0.5690 - val_y1_output_loss: 0.1219 - val_y2_output_loss: 0.4438 - val_y1_output_root_mean_squared_error: 0.3535 - val_y2_output_root_mean_squared_error: 0.6664
# Epoch 489/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3399 - y1_output_loss: 0.1249 - y2_output_loss: 0.2176 - y1_output_root_mean_squared_error: 0.3474 - y2_output_root_mean_squared_error: 0.4682 - val_loss: 1.1131 - val_y1_output_loss: 0.5361 - val_y2_output_loss: 0.5753 - val_y1_output_root_mean_squared_error: 0.7360 - val_y2_output_root_mean_squared_error: 0.7560
# Epoch 490/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2988 - y1_output_loss: 0.1222 - y2_output_loss: 0.1748 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.4198 - val_loss: 0.6276 - val_y1_output_loss: 0.1531 - val_y2_output_loss: 0.4695 - val_y1_output_root_mean_squared_error: 0.3966 - val_y2_output_root_mean_squared_error: 0.6857
# Epoch 491/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3862 - y1_output_loss: 0.1348 - y2_output_loss: 0.2487 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.5005 - val_loss: 0.5574 - val_y1_output_loss: 0.1188 - val_y2_output_loss: 0.4358 - val_y1_output_root_mean_squared_error: 0.3478 - val_y2_output_root_mean_squared_error: 0.6606
# Epoch 492/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3992 - y1_output_loss: 0.1396 - y2_output_loss: 0.2573 - y1_output_root_mean_squared_error: 0.3750 - y2_output_root_mean_squared_error: 0.5085 - val_loss: 0.5436 - val_y1_output_loss: 0.1218 - val_y2_output_loss: 0.4179 - val_y1_output_root_mean_squared_error: 0.3513 - val_y2_output_root_mean_squared_error: 0.6483
# Epoch 493/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3368 - y1_output_loss: 0.1198 - y2_output_loss: 0.2141 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.4647 - val_loss: 0.5303 - val_y1_output_loss: 0.1185 - val_y2_output_loss: 0.4052 - val_y1_output_root_mean_squared_error: 0.3487 - val_y2_output_root_mean_squared_error: 0.6393
# Epoch 494/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3180 - y1_output_loss: 0.1191 - y2_output_loss: 0.1988 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.4459 - val_loss: 1.0503 - val_y1_output_loss: 0.2622 - val_y2_output_loss: 0.7883 - val_y1_output_root_mean_squared_error: 0.5162 - val_y2_output_root_mean_squared_error: 0.8854
# Epoch 495/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4591 - y1_output_loss: 0.1437 - y2_output_loss: 0.3198 - y1_output_root_mean_squared_error: 0.3777 - y2_output_root_mean_squared_error: 0.5625 - val_loss: 1.2477 - val_y1_output_loss: 0.3207 - val_y2_output_loss: 0.9144 - val_y1_output_root_mean_squared_error: 0.5717 - val_y2_output_root_mean_squared_error: 0.9596
# Epoch 496/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5159 - y1_output_loss: 0.1557 - y2_output_loss: 0.3576 - y1_output_root_mean_squared_error: 0.3952 - y2_output_root_mean_squared_error: 0.5998 - val_loss: 0.7083 - val_y1_output_loss: 0.1562 - val_y2_output_loss: 0.5454 - val_y1_output_root_mean_squared_error: 0.3991 - val_y2_output_root_mean_squared_error: 0.7410
# Epoch 497/500
# 614/614 [==============================] - 0s 203us/sample - loss: 0.3473 - y1_output_loss: 0.1117 - y2_output_loss: 0.2331 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.4845 - val_loss: 0.6368 - val_y1_output_loss: 0.1510 - val_y2_output_loss: 0.4790 - val_y1_output_root_mean_squared_error: 0.3940 - val_y2_output_root_mean_squared_error: 0.6939
# Epoch 498/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3704 - y1_output_loss: 0.1270 - y2_output_loss: 0.2453 - y1_output_root_mean_squared_error: 0.3554 - y2_output_root_mean_squared_error: 0.4941 - val_loss: 0.6326 - val_y1_output_loss: 0.1264 - val_y2_output_loss: 0.4949 - val_y1_output_root_mean_squared_error: 0.3592 - val_y2_output_root_mean_squared_error: 0.7096
# Epoch 499/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3700 - y1_output_loss: 0.1242 - y2_output_loss: 0.2433 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.4947 - val_loss: 0.5707 - val_y1_output_loss: 0.1576 - val_y2_output_loss: 0.4166 - val_y1_output_root_mean_squared_error: 0.4004 - val_y2_output_root_mean_squared_error: 0.6406
# Epoch 500/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4507 - y1_output_loss: 0.1590 - y2_output_loss: 0.2878 - y1_output_root_mean_squared_error: 0.4006 - y2_output_root_mean_squared_error: 0.5387 - val_loss: 0.5386 - val_y1_output_loss: 0.1333 - val_y2_output_loss: 0.4060 - val_y1_output_root_mean_squared_error: 0.3691 - val_y2_output_root_mean_squared_error: 0.6343

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.5386 - y1_output_loss: 0.1371 - y2_output_loss: 0.4063 - y1_output_root_mean_squared_error: 0.3691 - y2_output_root_mean_squared_error: 0.6343
# Loss = 0.538554234938188, Y1_loss = 0.13712626695632935, Y1_mse = 0.3691471517086029, Y2_loss = 0.40625423192977905, Y2_mse = 0.6342591047286987

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
